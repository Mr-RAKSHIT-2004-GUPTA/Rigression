# %% [markdown]
# <a href="https://colab.research.google.com/github/Mr-RAKSHIT-2004-GUPTA/Rigression/blob/main/Decision_tree_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import load_iris

data = load_iris()
data.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
df = pd.DataFrame(data.data , columns = data.feature_names)
df['target'] = data.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
X = df.drop('target' , axis = 1)
y = df['target']

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X,y)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion='entropy')
model.fit(X_train , y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
# postpruning
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(model , filled=True)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[2] <= 2.45\nentropy = 1.583\nsamples = 112\nvalue = [39, 38, 35]'),
#  Text(0.4, 0.75, 'entropy = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.45, 0.8333333333333333, 'True  '),
#  Text(0.6, 0.75, 'x[3] <= 1.75\nentropy = 0.999\nsamples = 73\nvalue = [0, 38, 35]'),
#  Text(0.55, 0.8333333333333333, '  False'),
#  Text(0.4, 0.5833333333333334, 'x[1] <= 2.65\nentropy = 0.384\nsamples = 40\nvalue = [0, 37, 3]'),
#  Text(0.3, 0.4166666666666667, 'x[2] <= 4.95\nentropy = 0.779\nsamples = 13\nvalue = [0, 10, 3]'),
#  Text(0.2, 0.25, 'x[3] <= 1.6\nentropy = 0.439\nsamples = 11\nvalue = [0, 10, 1]'),
#  Text(0.1, 0.08333333333333333, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10, 0]'),
#  Text(0.3, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.4, 0.25, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.5, 0.4166666666666667, 'entropy = 0.0\nsamples = 27\nvalue = [0, 27, 0]'),
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion='entropy' , max_depth=3)
classifier.fit(X_train , y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
plt.figure(figsize=(15,10))
tree.plot_tree(classifier , filled=True)
# Out:
# [Text(0.375, 0.875, 'x[3] <= 0.8\nentropy = 1.583\nsamples = 112\nvalue = [39, 38, 35]'),
#  Text(0.25, 0.625, 'entropy = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.3125, 0.75, 'True  '),
#  Text(0.5, 0.625, 'x[3] <= 1.75\nentropy = 0.999\nsamples = 73\nvalue = [0, 38, 35]'),
#  Text(0.4375, 0.75, '  False'),
#  Text(0.25, 0.375, 'x[1] <= 2.65\nentropy = 0.384\nsamples = 40\nvalue = [0, 37, 3]'),
#  Text(0.125, 0.125, 'entropy = 0.779\nsamples = 13\nvalue = [0, 10, 3]'),
#  Text(0.375, 0.125, 'entropy = 0.0\nsamples = 27\nvalue = [0, 27, 0]'),
#  Text(0.75, 0.375, 'x[2] <= 4.85\nentropy = 0.196\nsamples = 33\nvalue = [0, 1, 32]'),
#  Text(0.625, 0.125, 'entropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.875, 0.125, 'entropy = 0.0\nsamples = 30\nvalue = [0, 0, 30]')]

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score , classification_report
accuracy_score(y_test , y_pred)
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.86      1.00      0.92        12
#            2       1.00      0.87      0.93        15
#
#     accuracy                           0.95        38
#    macro avg       0.95      0.96      0.95        38
# weighted avg       0.95      0.95      0.95        38

# %% [markdown]
# # ***prepruning***
#
# ---

# %%
params = {'criterion':['gini','entropy','log_loss'],
          'splitter':['best','random'],
          'max_depth' : [1,2,3,4,5,6],
          'max_features':['sqrt' , 'log2' , 'auto']}

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(DecisionTreeClassifier() , param_grid=params , cv=5 , scoring='accuracy')
grid.fit(X_train , y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5, 6],
#                          'max_features': ['sqrt', 'log2', 'auto'],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
grid.best_params_
# Out:
# {'criterion': 'log_loss',
#  'max_depth': 4,
#  'max_features': 'sqrt',
#  'splitter': 'random'}

# %%
grid.best_score_
# Out:
# 0.9561264822134387

# %%
y_pred  = grid.predict(X_test)

# %%
from sklearn.metrics import accuracy_score , classification_report
print(accuracy_score(y_test , y_pred))
print(classification_report(y_test , y_pred))
# Out:
# 0.9473684210526315
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.92      0.92      0.92        12
#            2       0.93      0.93      0.93        15
#
#     accuracy                           0.95        38
#    macro avg       0.95      0.95      0.95        38
# weighted avg       0.95      0.95      0.95        38
