# %% [markdown]
# <a href="https://colab.research.google.com/github/Mr-RAKSHIT-2004-GUPTA/Rigression/blob/main/laso_ridge_elastic_net.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
# The "mpg" dataset, which stands for "miles per gallon". It contains information about various car models and their characteristics, such as cylinders, displacement, horsepower, weight, acceleration, model year, origin, and miles per gallon (mpg) fuel efficiency.
#
# Here's a brief explanation of each column:
#
# mpg: Miles per gallon, representing the fuel efficiency of the car.
# cylinders: Number of cylinders in the engine.
# displacement: Engine displacement, the measure of the cylinder volume swept by all of the pistons of a piston engine.
# horsepower: The power of the engine, typically measured in horsepower (hp).
# weight: Weight of the car, often measured in pounds.
# acceleration: Acceleration of the car from 0 to 60 miles per hour (mph) in seconds.
# model year: Year of manufacturing of the car model.
# origin: Origin of the car, represented as a categorical variable (1: USA, 2: Europe, 3: Japan).
# name: The name of the car model.
# This dataset is commonly used for regression tasks, where the goal is to predict the fuel efficiency (mpg) of a car based on its other characteristics

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('mpg')
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.drop('name',inplace = True , axis = 1)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin
# 0          70    usa
# 1          70    usa
# 2          70    usa
# 3          70    usa
# 4          70    usa

# %%
df['horsepower'].fillna(df['horsepower'].median(),inplace = True)

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 25.0+ KB

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# dtype: object

# %%
df['origin'].value_counts()
# Out:
# origin
# usa       249
# japan      79
# europe     70
# Name: count, dtype: int64

# %%
df['origin'] = df['origin'].map({'usa':0,'japan':1,'europe':2})

# %%
df['origin'].astype(int)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 393    0
# 394    2
# 395    0
# 396    0
# 397    0
# Name: origin, Length: 398, dtype: int64

# %%
df.origin.value_counts()
# Out:
# origin
# 0    249
# 1     79
# 2     70
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
# dtypes: float64(4), int64(4)
# memory usage: 25.0 KB

# %%
#seperate X and Y

# %%
X = df.drop('mpg',axis = 1)
y = df['mpg']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,random_state = 2,test_size = 0.3)

# %%
#simple linear regression model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
for i ,column in enumerate(X_train.columns):
  print(f"the coeeficient for {column} is {model.coef_[i]}")
# Out:
# the coeeficient for cylinders is -0.48943031634992534
# the coeeficient for displacement is 0.025260023586458718
# the coeeficient for horsepower is -0.013895299784866378
# the coeeficient for weight is -0.007059112778078424
# the coeeficient for acceleration is 0.057085069882559826
# the coeeficient for model_year is 0.7884232824089383
# the coeeficient for origin is 1.9981649605565537

# %%
from sklearn.metrics import r2_score
y_pred = model.predict(X_test)
r2_linear = r2_score(y_test,y_pred)
print(f"the r2 score for linear model is {r2_linear}")
# Out:
# the r2 score for linear model is 0.8160231176904136

# %%
#Ridge regression
from sklearn.linear_model import Ridge
ridge_regression_model = Ridge(alpha = 0.1)
ridge_regression_model.fit(X_train , y_train)

for i , column in enumerate(X_train.columns):
  print(f"the coeeficient for {column} is {ridge_regression_model.coef_[i]}")
# Out:
# the coeeficient for cylinders is -0.4886085594229407
# the coeeficient for displacement is 0.025229054682163545
# the coeeficient for horsepower is -0.013879970558399537
# the coeeficient for weight is -0.0070586387975238975
# the coeeficient for acceleration is 0.05713238555366967
# the coeeficient for model_year is 0.7883258951470956
# the coeeficient for origin is 1.995997525568122

# %%
y_pred_ridge = ridge_regression_model.predict(X_test)
r2_ridge = r2_score(y_test,y_pred_ridge)
print(f"the r2 score for ridge model is {r2_ridge}")
# Out:
# the r2 score for ridge model is 0.8160751654916897

# %%
# we don't see much variation in coeff od ridge rigression as compared to linear rigression

# %%
from sklearn.linear_model import Lasso

# %%
lasso_regression_model = Lasso(alpha = 0.5)

# %%
lasso_regression_model.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.5)

# %%
for i ,column in enumerate(X_train.columns):
  print(f"the coefficient for {column} is {lasso_regression_model.coef_[i]}")
# Out:
# the coefficient for cylinders is -0.0
# the coefficient for displacement is 0.0022743893478212583
# the coefficient for horsepower is -0.010252545877627786
# the coefficient for weight is -0.006330986533327745
# the coefficient for acceleration is 0.0
# the coefficient for model_year is 0.6912890489866047
# the coefficient for origin is 0.45884419645958224

# %%
# feature coefficient are 0 , lasso helps in feature engineering

# %%
y_pred_lasso = lasso_regression_model.predict(X_test)
r2_lasso = r2_score(y_test,y_pred_lasso)
print(f"the r2 score for lasso regression {r2_lasso}")
# Out:
# the r2 score for lasso regression 0.8333271847965706

# %%
from sklearn.linear_model import ElasticNet

# %%
elastic_net_model = ElasticNet(alpha = 1 , l1_ratio = 0.5)
elastic_net_model.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=1)

# %%
for i,column in enumerate(X_train.columns):
  print(f"the coefficient for {column} is {elastic_net_model.coef_[i]}")
# Out:
# the coefficient for cylinders is -0.0
# the coefficient for displacement is 0.0
# the coefficient for horsepower is -0.010757273307390063
# the coefficient for weight is -0.006226957942526062
# the coefficient for acceleration is 0.0
# the coefficient for model_year is 0.6526469803329782
# the coefficient for origin is 0.1780074754049178

# %%
#Predict on the test set
y_pred_elastic_net = elastic_net_model.predict(X_test)

# Calculate the R2 score
r2_elastic_net = r2_score(y_test, y_pred_elastic_net)

print(f"R2 score for Elastic Net Regression: {r2_elastic_net}")
# Out:
# R2 score for Elastic Net Regression: 0.8317110977107209

# %% [markdown]
# **CROSS VALIDATION**

# %%
from sklearn.linear_model import LassoCV
lassocv = LassoCV(cv=5)
lassocv.fit(X_train,y_train)
y_pred = lassocv.predict(X_test)
score = r2_score(y_test,y_pred)
print(f"the r2 score for lasso cv is {score}")
# Out:
# the r2 score for lasso cv is 0.7783034678029813

# %%
from sklearn.linear_model import RidgeCV
ridgecv = RidgeCV(cv = 5)
ridgecv.fit(X_train,y_train)
y_pred = ridgecv.predict(X_test)
score = r2_score(y_test,y_pred)
print(f"the r2 score for ridge cv is {score}")
# Out:
# the r2 score for ridge cv is 0.8204207781054915

# %%
from sklearn.linear_model import ElasticNetCV
elasticnet = ElasticNetCV(cv = 5)
elasticnet.fit(X_train,y_train)
y_pred = elasticnet.predict(X_test)
score = r2_score(y_test,y_pred)
print(f"the r2 score for elastic net cv is {score}")
# Out:
# the r2 score for elastic net cv is 0.7594425499282782

# %%
elasticnet.get_params()
# Out:
# {'alphas': None,
#  'copy_X': True,
#  'cv': 5,
#  'eps': 0.001,
#  'fit_intercept': True,
#  'l1_ratio': 0.5,
#  'max_iter': 1000,
#  'n_alphas': 100,
#  'n_jobs': None,
#  'positive': False,
#  'precompute': 'auto',
#  'random_state': None,
#  'selection': 'cyclic',
#  'tol': 0.0001,
#  'verbose': 0}
